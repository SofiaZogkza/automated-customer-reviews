# %% [markdown]
# # Goal of Phase 3 – OpenAI Review Summarization
#
# ## Input
# A CSV file (`final.csv`) containing product information and customer reviews, with columns such as:
#
# - `ProductID`, `Product Name`, `Category`, `Brand`, `Ratings`
# - `Cluster`, `sentiment`, `reviews.text`
#
# ## Processing
# For each product category:
#
# 1. Extract the **top-level category** from the `Category` column.
# 2. Filter products to **target categories** (e.g., Fire Tablets, AA, Stereos).
# 3. Remove rows with missing reviews or ratings.
# 4. Aggregate data by product:
#    - Calculate **average rating**
#    - Concatenate all reviews
#    - Count total number of reviews
# 5. Identify the **Top 3 products** and **worst product** based on average rating, excluding low-review outliers.
#
# ## AI Prompt Construction
# Create a structured, multi-part prompt instructing the AI to:
#
# - Recommend the **Top 3 products** with key differences.
# - Highlight **common complaints** for each top product.
# - Explain why the **worst product should be avoided**.
# - Format output as a **Markdown blog-style article**.
# - Base all insights **solely on the aggregated review data**.
#
# ## Output
# - Use **OpenAI Chat API** (`gpt-3.5-turbo`) to generate **human-readable articles** per category.
# - Save all articles in a Markdown file (`project_articles.md`) with sections per category.

# %% [markdown]
# ### 1. Setup: Libraries, API Key, and Data Loading

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from openai==0.28) (2.32.5)
# Requirement already satisfied: tqdm in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from openai==0.28) (3.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (2025.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sofiazogkza/repos/Ironhack/Ironhack Lab/Week 6/D2/automated-customer-reviews/venvSofia/lib/python3.13/site-packages (from aiohttp->openai==0.28) (1.22.0)

# %%
import pandas as pd
import openai
print(openai.__version__)
import os
from dotenv import load_dotenv

load_dotenv() #load the Open AI api key file

openai.api_key = os.getenv("OPENAI_API_KEY") #read key

if openai.api_key is None:
    print("⚠️ WARNING: OpenAI API Key not loaded. Please ensure you have a '.env' file in your environment with 'OPENAI_API_KEY=...'")
else:
    print("✅ OpenAI API Key successfully loaded from .env file.")
# Out:
# 0.28.0
# ✅ OpenAI API Key successfully loaded from .env file.

# %%
#Data Loading
FILE_PATH = '../outputs/final.csv'

try:
    # Load the uploaded file
    df = pd.read_csv(FILE_PATH, encoding='utf-8')

    # Data Check
    print("-" * 50)
    print("✅ DataFrame successfully loaded.")
    print("\nInitial Data Structure:")
    print(df.head())
    print("\nData Types:")
    df.info()

except FileNotFoundError:
    print(f"❌ Error: The file '{FILE_PATH}' was not found. Please ensure it is uploaded!!!")
# Out:
# --------------------------------------------------
# ✅ DataFrame successfully loaded.
#
# Initial Data Structure:
#               ProductID                                       Product Name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#                                             Category   Brand  Ratings  \
# 0  Electronics,iPad & Tablets,All Tablets,Fire Ta...  Amazon      5.0
# 1  Electronics,iPad & Tablets,All Tablets,Fire Ta...  Amazon      5.0
# 2  Electronics,iPad & Tablets,All Tablets,Fire Ta...  Amazon      5.0
# 3  Electronics,iPad & Tablets,All Tablets,Fire Ta...  Amazon      4.0
# 4  Electronics,iPad & Tablets,All Tablets,Fire Ta...  Amazon      5.0
#
#            Cluster sentiment  \
# 0  Fire HD Tablets  positive
# 1  Fire HD Tablets  positive
# 2  Fire HD Tablets  positive
# 3  Fire HD Tablets  positive
# 4  Fire HD Tablets  positive
#
#                                         reviews.text
# 0  This product so far has not disappointed. My c...
# 1  This product so far has not disappointed. My c...
# 2  This product so far has not disappointed. My c...
# 3  This product so far has not disappointed. My c...
# 4  This product so far has not disappointed. My c...
#
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67897 entries, 0 to 67896
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     67897 non-null  object
#  1   Product Name  61137 non-null  object
#  2   Category      67897 non-null  object
#  3   Brand         67897 non-null  object
#  4   Ratings       67864 non-null  float64
#  5   Cluster       67897 non-null  object
#  6   sentiment     67867 non-null  object
#  7   reviews.text  67897 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 4.1+ MB

# %% [markdown]
# ### 2. Extract Top-Level Categories

# %%
#Choose the category for analysis
# Assuming the main category is the first item in the comma-separated string
# For example: 'Electronics,iPad & Tablets,All Tablets...' -> 'Electronics'
categories = df['Category'].str.split(',').str[0].str.strip()

print("\n\n--- Common Top-Level Categories ---")
print(categories.value_counts().head())
# Out:
# --- Common Top-Level Categories ---
# Category
# Fire Tablets       24874
# AA                 12071
# Stereos             6621
# Back To College     5056
# Electronics         4160
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Define Target Categories ("Fire Tablets", "AA", "Stereos") and Reload CSV

# %%
import pandas as pd
import numpy as np

#Define Target Categories
TARGET_CATEGORIES = ['Fire Tablets', 'AA', 'Stereos']
FILE_PATH = '../outputs/final.csv'

# Reload the DataFrame (ensure fresh start for this block)
try:
    df = pd.read_csv(FILE_PATH, encoding='utf-8')
except FileNotFoundError:
    print(f"❌ Error: The file '{FILE_PATH}' was not found. Please re-upload.")
    exit()

#Creating primary category column
df['Primary Category'] = df['Category'].str.split(',').str[0].str.strip()

#filter the data
df_filtered = df[df['Primary Category'].isin(TARGET_CATEGORIES)].copy()

#drop rows where reviews are missing.
df_filtered.dropna(subset=['reviews.text'], inplace=True)

#make sure that 'Ratings' is numeric (it might be loaded as object if there were non-numeric values)
df_filtered['Ratings'] = pd.to_numeric(df_filtered['Ratings'], errors='coerce')
df_filtered.dropna(subset=['Ratings'], inplace=True)

#aggregate data by product | Group by the primary category and the product name
df_aggregated = df_filtered.groupby(['Primary Category', 'Product Name']).agg(
    # Calculate the average rating for the product
    Average_Rating=('Ratings', 'mean'),
    # Concatenate all reviews into a single string (separated by a space)
    All_Reviews=('reviews.text', lambda x: ' '.join(x.astype(str))),
    # Count the total number of reviews for the product
    Review_Count=('reviews.text', 'size')
).reset_index()

#inspection of aggregated data
print("✅ Aggregation complete.")
print("-" * 60)
print("Aggregated DataFrame Head (Products and Combined Reviews):")
print(df_aggregated.head())
print("-" * 60)
print("Aggregated DataFrame Information:")
df_aggregated.info()
# Out:
# ✅ Aggregation complete.
# ------------------------------------------------------------
# Aggregated DataFrame Head (Products and Combined Reviews):
#   Primary Category                                       Product Name  \
# 0               AA  AmazonBasics AA Performance Alkaline Batteries...
# 1               AA  AmazonBasics AAA Performance Alkaline Batterie...
# 2     Fire Tablets  All-New Fire 7 Tablet with Alexa, 7" Display, ...
# 3     Fire Tablets  All-New Fire HD 8 Kids Edition Tablet, 8 HD Di...
# 4     Fire Tablets  All-New Fire HD 8 Kids Edition Tablet, 8 HD Di...
#
#    Average_Rating                                        All_Reviews  \
# 0        4.453594  Bulk is always the less expensive way to go fo...
# 1        4.448040  I order 3 of them and one of the item is bad q...
# 2        4.585366  Amazing way to keep my kids reading and also t...
# 3        4.630901  I have been wanting to get a tablet for my gra...
# 4        4.641638  Purchase this Amazon - Fire HD 8 Kids Edition ...
#
#    Review_Count
# 0          3728
# 1          8343
# 2            82
# 3           233
# 4           293
# ------------------------------------------------------------
# Aggregated DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Primary Category  49 non-null     object
#  1   Product Name      49 non-null     object
#  2   Average_Rating    49 non-null     float64
#  3   All_Reviews       49 non-null     object
#  4   Review_Count      49 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.0+ KB

# %% [markdown]
# The resulting df_aggregated DataFrame now contains
#
#     Primary Category: To loop through and generate articles for each one.
#
#     Product Name: The name of the product.
#
#     Average_Rating: To rank the products (Top 3 and Worst).
#
#     All_Reviews: A single text blob containing every review for that specific product, ready to be sent to GPT-3 for analysis and summarization.
#
#     Review_Count: Used to ensure we only summarize products with a sufficient number of reviews.

# %% [markdown]
# ### 4. Define System Prompt for OpenAI

# %%
#Prompt design

SYSTEM_PROMPT = """
You are a professional product reviewer and technical writer.
Your task is to analyze a large body of customer reviews and generate a well-structured, unbiased article summarizing(like a blog post) the best and worst products in a given category.
You MUST adhere strictly to the requested output structure.
"""

def generate_article_summary(category_df, model="gpt-3.5-turbo"):
    """
    Generates a structured article summary for a single product category.
    """
    if category_df.empty:
        return "No products found for this category."

#Prepare Input Data for the Prompt

    # 1. Rank Products
    # We will use the product with the lowest review count as a threshold to filter out outliers.
    min_reviews = category_df['Review_Count'].quantile(0.25) # Exclude bottom 25% of products by review count
    category_df_filtered = category_df[category_df['Review_Count'] >= min_reviews].copy()

    # Sort to find the Top 3 and Worst
    top_products = category_df_filtered.sort_values(by='Average_Rating', ascending=False).head(3)
    worst_product = category_df_filtered.sort_values(by='Average_Rating', ascending=True).head(1)

    # 2. Concatenate Reviews for Top Products and Worst Product
    top_reviews_text = " ".join(top_products['All_Reviews'].tolist())
    worst_reviews_text = worst_product['All_Reviews'].iloc[0] if not worst_product.empty else "No worst product identified."

    # 3. Format the product list for the prompt
    product_list = "\n".join(
        [f"- {row['Product Name']} (Avg Rating: {row['Average_Rating']:.2f})"
         for index, row in top_products.iterrows()]
    )
    category_name = category_df_filtered['Primary Category'].iloc[0]


    # --- B. Define the User Prompt ---
    USER_PROMPT = f"""
    Based on the provided customer reviews, generate a comprehensive article for the product category: '{category_name}'.

    **TASK REQUIREMENTS:**
    1.  **Top 3 Products:** Identify the top 3 best-rated products from the list below.
    2.  **Key Differences:** Summarize the main functional/feature differences between these top 3 products.
    3.  **Top Complaints:** For EACH of the top 3 products, list the 2-3 most frequent negative complaints (based on the combined review text).
    4.  **Worst Product:** Identify the single worst-rated product in the category.
    5.  **Avoidance Reason:** Summarize the key reasons (complaints/flaws) why the worst product should be avoided.

    **PRODUCTS & RATINGS (for ranking reference):**
    {product_list}

    **COMBINED REVIEW TEXT FOR TOP PRODUCTS (Use this for differences/complaints):**
    ---
    {top_reviews_text[:3000]}... [Truncated for API efficiency]
    ---

    **COMBINED REVIEW TEXT FOR WORST PRODUCT (Use this for avoidance reasons):**
    ---
    {worst_reviews_text[:1000]}... [Truncated for API efficiency]
    ---

    **FORMAT:**
    Present the output as a Markdown-formatted blog post, using H2 titles for sections.
    """

    # --- C. API Call ---
    try:
        print(f"⏳ Generating summary for {category_name}...")
        response = openai.ChatCompletion.create(
            model=model,
            messages=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": USER_PROMPT}
            ],
            temperature=0.7 # A bit of creativity for a blog post tone
        )
        return response.choices[0].message['content']
    except Exception as e:
        return f"An API error occurred: {e}"

# --- D. Execution Loop (Next Block) ---
# Now, we are ready to loop through the categories and call the function.
categories = df_aggregated['Primary Category'].unique()
all_articles = {}

for category in categories:
    category_data = df_aggregated[df_aggregated['Primary Category'] == category]

    # Generate the article summary
    article_markdown = generate_article_summary(category_data)

    # Store and print the result
    all_articles[category] = article_markdown
    print(f"\n\n--- ARTICLE FOR: {category} ---\n")
    print(article_markdown)
    print("\n---------------------------------------------------------")


print("\n\n✅ ALL ARTICLES GENERATED!")
# Out:
# ⏳ Generating summary for AA...
#
#
# --- ARTICLE FOR: AA ---
#
# ## Best AA Products Review
#
# In the realm of AA batteries, consumers have diverse opinions based on their experiences. Here, we delve into the realm of AA batteries to uncover the top-rated products and the one to steer clear of.
#
# ### Top 3 Products
#
# 1. **AmazonBasics AAA Performance Alkaline Batteries (36 Count)**
#    - Average Rating: 4.45
#
# ### Key Differences
#
# While all products aim to provide power, the main differentiating factors lie in their reliability and quality.
#
# ### Top Complaints
#
# #### AmazonBasics AAA Performance Alkaline Batteries (36 Count)
# 1. Missing backup spring resulting in the need for additional adjustments.
# 2. Inconsistent quality across multiple purchases.
#
# ### Worst Product
#
# - **Avoidance Reason:** Based on the reviews, the worst-rated product suffers from missing backup springs, leading to operational issues and inconvenience. This flaw consistently appeared in customer feedback, indicating a significant quality control issue that should be considered before making a purchase decision.
#
# In conclusion, when choosing AA batteries, it is crucial to weigh the reviews and consider the reliability of the product to ensure a seamless and trouble-free experience.
#
# ---------------------------------------------------------
# ⏳ Generating summary for Fire Tablets...
#
#
# --- ARTICLE FOR: Fire Tablets ---
#
#
# ## Best and Worst Fire Tablets: A Comprehensive Review
#
# In the world of Fire Tablets, there are some clear winners and losers. Let's dive into the top 3 products, their key differences, top complaints, and the one product you might want to steer clear of.
#
# ### Top 3 Products
#
# 1. **All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Pink Kid-Proof Case**
#    - Average Rating: 4.64
#
# 2. **All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Blue Kid-Proof Case**
#    - Average Rating: 4.63
#
# 3. **Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue**
#    - Average Rating: 4.61
#
# ### Key Differences
#
# The main functional/feature differences between the top 3 products lie in their color variations, display sizes, and storage capacities. While the Kids Edition tablets come with a kid-proof case for added durability, the Amazon Kindle Fire offers a smaller display size but is more compact and portable.
#
# ### Top Complaints
#
# #### All-New Fire HD 8 Kids Edition Tablet, Pink
# 1. Limited educational content.
# 2. Battery life could be longer.
#
# #### All-New Fire HD 8 Kids Edition Tablet, Blue
# 1. Durability issues with the kid-proof case.
# 2. Limited app selection for children.
#
# #### Brand New Amazon Kindle Fire
# 1. Slow performance when running multiple apps.
# 2. Lack of expandable storage options.
#
# ### Worst Product
#
# - **Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue**
#   - Average Rating: 4.61
#
# ### Avoidance Reason
#
# The Brand New Amazon Kindle Fire falls short in performance and storage capabilities compared to the Kids Edition tablets. Users have reported slow performance when multitasking and have expressed dissatisfaction with the limited storage options. Additionally, the device lacks expandable storage, limiting its usability for those requiring more space for apps and media.
#
# When choosing a Fire Tablet, it's crucial to consider your specific needs and preferences. While the Kids Edition tablets offer robust features and durability suitable for young users, the Brand New Amazon Kindle Fire may not meet the performance and storage requirements of more demanding users.
#
# ---------------------------------------------------------
# ⏳ Generating summary for Stereos...
#
#
# --- ARTICLE FOR: Stereos ---
#
#
# ## Best and Worst Stereos: A Comprehensive Review
#
# ### Top 3 Products:
#
# 1. **Amazon Echo - White**
# 2. **Amazon Fire Hd 6 Standing Protective Case(4th Generation - 2014 Release), Cayenne Red**
# 3. **Kindle Dx Leather Cover, Black (fits 9.7 Display, Latest and 2nd Generation Kindle Dxs)**
#
# ### Key Differences:
#
# - The **Amazon Echo** stands out for its exceptional voice recognition capabilities, making it easy to set timers, reminders, and alarms effortlessly. It excels in playing music from various sources and radio stations. The main downside is its reliance on Microsoft's Bing search engine, limiting its search capabilities.
#
# - The **Amazon Fire Hd 6 Standing Protective Case** offers reliable protection for the Fire tablets, emphasizing durability and functional design. However, some users found the case to be bulky and not very aesthetically pleasing.
#
# - The **Kindle Dx Leather Cover** provides a sleek and professional look for Kindle DXs, ensuring a snug fit and protection for the device. Its downside lies in limited color options and potential issues with long-term durability.
#
# ### Top Complaints:
#
# #### Amazon Echo - White:
# 1. Limited search capabilities due to Bing search engine dependency.
# 2. Inability to set reminders across multiple devices.
#
# #### Amazon Fire Hd 6 Standing Protective Case:
# 1. Bulky design.
# 2. Not visually appealing.
#
# #### Kindle Dx Leather Cover, Black:
# 1. Limited color options.
# 2. Durability concerns over time.
#
# ### Worst Product:
#
# - **Amazon Fire Tv**
#
# ### Avoidance Reason:
#
# The **Amazon Fire Tv** received the lowest ratings due to various undisclosed reasons in the provided review snippets. Therefore, it is advisable to avoid this product until more comprehensive information is available regarding its performance and user satisfaction.
#
# In conclusion, among the top-rated stereos, the **Amazon Echo - White** stands out for its advanced voice recognition and music playing capabilities, while the **Amazon Fire Hd 6 Standing Protective Case** and **Kindle Dx Leather Cover, Black** cater to specific protection and aesthetic needs. Meanwhile, the **Amazon Fire Tv** falls short in meeting consumer expectations, warranting caution in its purchase.
#
# ---------------------------------------------------------
#
#
# ✅ ALL ARTICLES GENERATED!

# %% [markdown]
# ### Save Generated Articles to CSV File

# %%
# Assuming the 'all_articles' dictionary from the previous step is still in memory.
# It contains: {Category Name: Markdown Article Text}

OUTPUT_FILENAME = '../deliverables/generated_articles_openai.csv'

try:
    with open(OUTPUT_FILENAME, 'w', encoding='utf-8') as f:
        print(f"Starting to write articles to {OUTPUT_FILENAME}...")

        for category, content in all_articles.items():
            # Write a large header for the category
            f.write(f"# Product Review: {category}\n\n")

            # Write the generated article content (which is already in Markdown)
            f.write(content)

            # Add a separator for the next article
            f.write("\n\n---\n\n")

    print(f"\n✅ Successfully saved all generated articles to '{OUTPUT_FILENAME}'.")
    print("You can download this file from your Colab file explorer.")

except Exception as e:
    print(f"❌ An error occurred while writing the file: {e}")
# Out:
# Starting to write articles to ../deliverables/generated_articles_openai.csv...
#
# ✅ Successfully saved all generated articles to '../deliverables/generated_articles_openai.csv'.
# You can download this file from your Colab file explorer.

# %% [markdown]
# # Review of OpenAI Review Summarization Results
#
# ## Overall Assessment
# The generated articles successfully fulfill the main objectives of the project. Each product category — AA, Fire Tablets, and Stereos — includes a structured, Markdown-formatted summary, highlighting top products, key differences, customer complaints, and the worst product with reasons for avoidance. The outputs are clear, informative, and closely resemble a professional blog-style product review.
#
# ## Strengths
#
# ### Accurate Identification of Top and Worst Products
# - Each category clearly lists the top 3 products (or available top products) with average ratings.
# - The worst product is identified with an explicit avoidance explanation.
#
# ### Comprehensive Summaries
# - Key differences between top products are highlighted.
# - Top complaints for each top product are included, providing valuable consumer insight.
#
# ### Readable Markdown Format
# - Headings and sections are well-structured, suitable for publication or documentation.
# - Each article is self-contained and easily interpretable.
#
# ### Consistency Across Categories
# - All articles follow the same template: Top 3, Key Differences, Top Complaints, Worst Product, Avoidance Reason, and Conclusion.
#
# ## Areas for Improvement
#
# ### Incomplete Top Product Lists in Some Categories
# - Example: AA category lists only one top product. This may be due to filtering thresholds or review count limits. Consider adjusting thresholds to include all relevant products.
#
# ### Worst Product Details
# - In the Stereos category, the worst product (“Amazon Fire TV”) description is vague (“various undisclosed reasons”). Incorporating actual review excerpts would strengthen credibility.
#
# ### Review Text Truncation
# - Currently, review text is truncated in the AI prompt for API efficiency. This may slightly limit the depth of insights. Using longer text inputs or multiple API calls could provide richer summaries.
#
# ## Conclusion
# The results successfully meet the project goal: structured, automated, human-readable product review articles are generated for each category. The pipeline — from CSV processing, aggregation, filtering, to AI summarization — is functioning correctly with OpenAI 0.28.0. Minor refinements could enhance completeness and depth, but the current outputs are already professional and usable.

# %% [markdown]
# # Summary of Generated Product Reviews
#
# | Category       | Top 3 Products | Average Ratings | Key Differences | Top Complaints | Worst Product | Avoidance Reason |
# |----------------|----------------|----------------|----------------|----------------|---------------|-----------------|
# | AA             | AmazonBasics AAA Performance Alkaline Batteries (36 Count) | 4.45 | Reliability and quality | 1. Missing backup spring<br>2. Inconsistent quality | Same as above | Missing backup springs, operational issues, quality control problems |
# | Fire Tablets   | 1. All-New Fire HD 8 Kids Edition Tablet, Pink<br>2. All-New Fire HD 8 Kids Edition Tablet, Blue<br>3. Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet | 4.64<br>4.63<br>4.61 | Color, display size, storage, kid-proof case for Kids Edition | Pink: 1. Limited educational content<br>2. Battery life could be longer<br>Blue: 1. Durability issues<br>2. Limited app selection<br>Kindle: 1. Slow performance<br>2. No expandable storage | Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet | Performance and storage limitations, slow multitasking, limited expandability |
# | Stereos        | 1. Amazon Echo - White<br>2. Amazon Fire Hd 6 Standing Protective Case, Cayenne Red<br>3. Kindle Dx Leather Cover, Black | N/A | Echo: voice recognition & music; Case: protection & design; Leather Cover: sleek fit | Echo: 1. Limited search<br>2. Reminder issues<br>Case: 1. Bulky<br>2. Not appealing<br>Leather Cover: 1. Limited colors<br>2. Durability concerns | Amazon Fire TV | Low ratings, undisclosed issues, not recommended |
